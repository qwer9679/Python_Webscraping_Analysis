# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
url = 'https://news.daum.net/economy'

req_header = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36'
}

res = requests.get(url, headers=req_header)
res.encoding = 'utf-8'
if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    # CSS 선택자
    li_tag = soup.select("div.sa_text a[href*='https://news.daum.net/economy/']")
    
    for li_tag in soup.select('ul.list_newsheadline2 li'):
        a_tag = li_tag.find('a')
        link = a_tag['href']	
            
        strong_tag = li_tag.select_one('div.cont_thumb strong.tit_txt')
        title = strong_tag.text.strip()

        print(title)
        print(link)
        print('-'*40)
# Out:
# 부동산과 정치 [취재파일]
# https://v.daum.net/v/20260206112702703
# ----------------------------------------
# "영월 대박" 만세 부른 미국…5천만 톤의 '파란 보석' [취재파일]
# https://v.daum.net/v/20260206112116449
# ----------------------------------------
# '디지털 금' 비트코인 위기…"죽음의 소용돌이" 경고 나왔다, 왜
# https://v.daum.net/v/20260206111444051
# ----------------------------------------
# 지난해 경상수지, 반도체 발판 '흑자' 신기록 쏟아졌다⋯한은 "올해도 긍정적" [종합]
# https://v.daum.net/v/20260206110503592
# ----------------------------------------
# [타파의 시선] 4천억 '탈세왕' 마저 감싸는 국세청의 비밀주의
# https://v.daum.net/v/20260206110124350
# ----------------------------------------
# '외인 vs 개인 수급전쟁'..삼전·닉스 4조원 어치 던진 외국인 떠나나?
# https://v.daum.net/v/20260206105208919
# ----------------------------------------
# 쭉쭉 늘더니 국민연금마저 뛰어넘었다…서학개미 해외주식투자 450억달러(종합)
# https://v.daum.net/v/20260206104305391
# ----------------------------------------
# '반도체 활황'에 작년 경상흑자 1천231억弗…12월 187억弗 '역대 최대'(종합)
# https://v.daum.net/v/20260206101901115
# ----------------------------------------
# 달 탐사로 가속화되는 우주 시장 개척 경쟁! [취재파일]
# https://v.daum.net/v/20260206100609345
# ----------------------------------------

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

req_header = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36'
}

# 응답(response)이 OK 이면
res = requests.get(url, headers=req_header)

if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")))
    # CSS 선택자
    a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
    print(type(a_tags), type(a_tags[0]))
    for a_tag in a_tags:
        title = a_tag.text.strip()
        link = a_tag['href']
        print(title, link)
# print(soup.select("div.sa_text a[href*='mnews/article']"))

# <a> 태그 리스트 순회하기    
else:
    # 응답(response)이 Error 이면 status code 출력    
    print(f'Error Code = {res.status_code}')
# Out:
# https://news.naver.com/section/105
# 88
# <class 'bs4.element.ResultSet'> <class 'bs4.element.Tag'>
# 사상 첫 연간 매출 12조원 돌파…네이버 최수연 “검색 넘어 에이전틱 AI로 수익성 강화” https://n.news.naver.com/mnews/article/016/0002596941
#  https://n.news.naver.com/mnews/article/comment/016/0002596941
# 네이버, '지식인 노출 사고' 사과⋯"사이트 링크 모두 제외, 재발 방지 점검" https://n.news.naver.com/mnews/article/031/0001003344
#  https://n.news.naver.com/mnews/article/comment/031/0001003344
# KAIST, K바이오 핵심 거점 ‘오송 KAIST 바이오 스퀘어’ 개소 https://n.news.naver.com/mnews/article/082/0001365964
#  https://n.news.naver.com/mnews/article/comment/082/0001365964
# 넷마블, 2025년 4분기 컨센서스 부합…주주환원 긍정적-다올證 https://n.news.naver.com/mnews/article/014/0005474419
#  https://n.news.naver.com/mnews/article/comment/014/0005474419
# 최수연 네이버 CEO "올해 로봇 실험 실외로 확장"[컨콜] https://n.news.naver.com/mnews/article/015/0005247832
#  https://n.news.naver.com/mnews/article/comment/015/0005247832
# 구글, 고정밀 지도 국외 반출 보완서류 제출 https://n.news.naver.com/mnews/article/422/0000830908
#  https://n.news.naver.com/mnews/article/comment/422/0000830908
# 한국형 포켓몬 꿈꾼다…데브시스터즈, '쿠키런 유니버스' 발표 https://n.news.naver.com/mnews/article/001/0015889544
#  https://n.news.naver.com/mnews/article/comment/001/0015889544
